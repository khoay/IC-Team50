# %%
import pandas as pd

# Assuming the file is named 'your_file.csv'
df = pd.read_csv('FF_SR_ data.csv')
df_cleaned = df.dropna(subset=["SR Min", "SR Max", "SR Mean per 100g", "SR Num_Data_pts"])
df_cleansed = df_cleaned.fillna(0, inplace=True)


df_cleaned.to_csv('CLEANED.csv', index=False)



df_cleaned.head(50)
# Out:
# /var/folders/wr/cdyywg6x2rx26m9s_41pb2800000gn/T/ipykernel_19816/3350074762.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleansed = df_cleaned.fillna(0, inplace=True)
#     FF_NDB  SR_NDB  food_category_id  \
# 29   11056   11056                11
# 30   11056   11056                11
# 31   11056   11056                11
# 32   11056   11056                11
# 33   11056   11056                11
# 34   11056   11056                11
# 35   11056   11056                11
# 37   11056   11056                11
# 38   11056   11056                11
# 40   11056   11056                11
# 41   11056   11056                11
# 42   11056   11056                11
# 43   11056   11056                11
# 44   11056   11056                11
# 45   11056   11056                11
# ...
